# %% [markdown]
# # Syntax and Semantics in Python:
# - ## Topics Covered:
# 1. Single line comments and multiline comments
# 2. Definition of Syntax and Semantics
# 3. Basic Syntax Rules in Python
# 4. Understanding Semantics in Python
# 5. Common Syntax Errors and How to Avoid Them

# %% [markdown]
# - Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structure programs in a language. In simpler Terms ,Syntax is about the correct arrangemsnts of words and symbols in a code

# %% [markdown]
# - Semantics refers to the meaning of interpretation of the symbols,characters and commands in a language. it is about what the code is supposed to do when it runs.

# %%
## Case sensitive language (single line comments)
## (''' Multi line comments in jupyter Notebook it is not valid ''')

# %%
# Basic syntax Rules in Python
## Case sensitivity - python is case sensitive
name="Daksh"
Name="Kumar"
print(name)
print(Name)
# Out:
# Daksh
# Kumar

# %% [markdown]
# ### Indentation
# Indentation in python is used to define the structure and hierarchy of the code. Unlike many other programming language that use braces{} to delimit block of Code ,Python uses indentation to determine the grouping of statements. This means that all the statements within a Block must be indented at same level.

# %%
## Indentation
## Python uses Indentation to  define block a code, consistent use of spaces (commonly 4) or tab isrequired.
age = 35
if age>30:

    print(age)

print(age)   # Outside the if block
# Out:
# 35
# 35

# %%
age=32
if age>30:
print(age)
# Out:
#   Cell In[29], line 3
#     print(age)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# Line continuation
## use a backslash(\) to continue a statement to the next line 
total=3+4+5+6+7+\
4+5
print(total)
# Out:
# 34

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understand  Semnatics In Python
# variable assignment
age=32 ##age is an integer
name="Daksh" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
variable="Daksh"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Name Error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 ## Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code exmaples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block

# %% [markdown]
# ### Conclusion:
# Understanding the syntax and semantics of Python is crucial for writing correct and meaningful programs. Syntax ensures the code is properly structured, while semantics ensures the code behaves as expected. Mastering these concepts will help in writing efficient and error-free Python code.
